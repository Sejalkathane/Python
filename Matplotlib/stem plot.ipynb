# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6]
y=[54,17,32,68,34,66]
plt.stem(x,y,linefmt=":",markerfmt="r*",bottom=0,basefmt="g"
        ,label="CPP",use_line_collection=False,orientation="horizontal")
plt.legend()
plt.show()

# we can change line structure also
# Out:
# C:\Users\SEJALK~1\AppData\Local\Temp/ipykernel_11756/1408284998.py:4: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x,y,linefmt=":",markerfmt="r*",bottom=0,basefmt="g"
